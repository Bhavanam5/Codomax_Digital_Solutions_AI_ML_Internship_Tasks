# %%
# Variables and Data Types
name = "Bhavana M"          # text (string)
age = 22                  # whole number (integer)
height = 5.4               # decimal number (float)
is_student = True          # True/False (boolean)

print(name, age, height, is_student)
print(type(name), type(age), type(height), type(is_student))
# Out:
# Bhavana M 22 5.4 True
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
# Operators
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Is a greater than b?", a > b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Is a greater than b? True

# %%
# Loops
for i in range(1, 6):
    print("Study hour:", i)
# Out:
# Study hour: 1
# Study hour: 2
# Study hour: 3
# Study hour: 4
# Study hour: 5

# %%
# Functions
def greet_student(student_name):
    return f"Hello, {student_name}! Ready to study?"

message = greet_student("Bhavana M")
print(message)
# Out:
# Hello, Bhavana M! Ready to study?

# %%
# Simple program: study hours tracker
def predict_effort(hours):
    if hours < 2:
        return "Low effort"
    elif hours < 5:
        return "Moderate effort"
    else:
        return "High effort"

study_days = [1, 3, 6, 2, 8]

for hours in study_days:
    print(f"{hours} hours -> {predict_effort(hours)}")
# Out:
# 1 hours -> Low effort
# 3 hours -> Moderate effort
# 6 hours -> High effort
# 2 hours -> Moderate effort
# 8 hours -> High effort
